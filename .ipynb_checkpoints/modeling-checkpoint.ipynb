# %%
# put all import statements here, don't forget to run this cell whenever you add new stuff
import pandas as pd
import numpy as np
import math
from MissingDataScript import fillMissing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR

# %%
# only run this cell once per jupyter notebook session
cleaned_data = pd.read_csv('output.csv', low_memory=False)
raw_data = pd.read_csv('background.csv', low_memory=False)

# %%
cleaned_data
# Out:
#       challengeID  m1intmon  m1intyr  m1lenhr  m1lenmin  cm1twoc  cm1fint  \
# 0               1         1      1.0        1        40      1.0        0
# 1               2         1      1.0        0        40      1.0        1
# 2               3         1      1.0        0        35      1.0        1
# 3               4         1      1.0        0        30      1.0        1
# 4               5         1      1.0        0        25      1.0        1
# 5               6         1      1.0        0        25      1.0        1
# 6               7         1      1.0        0        35      1.0        1
# 7               8         1      1.0        1        10      1.0        1
# 8               9         1      1.0        0        30      1.0        1
# 9              10         1      1.0        0        33      1.0        1
# 10             11         1      1.0        0        40      1.0        1
# 11             12         1      1.0        0        23      1.0        1
# ...

# %% [markdown]
# ## Build an outcome-specific model to predict and analyze one of the six outcomes

# %%
# read train.csv into pandas DataFrame
y_train = pd.read_csv('train.csv')
y_test = pd.read_csv('test.csv')

# %%
# it looks like the test and train sets are a little imbalanced
y_test.shape[0] / (y_test.shape[0] + y_train.shape[0])
# Out:
# 0.4286099137931034

# %%
# copy series from cleaned_data that match child challengeIDs in train.csv
X_train = pd.concat([pd.DataFrame(cleaned_data.loc[cleaned_data['challengeID'] == ID]) 
                     for index, ID in y_train['challengeID'].items()])

# %%
X_train.shape
# Out:
# (2121, 12943)

# %%
# copy series from cleaned_data that match child challengeIDs in test.csv
X_test = pd.concat([pd.DataFrame(cleaned_data.loc[cleaned_data['challengeID'] == ID]) 
                    for index, ID in y_test['challengeID'].items()])

# %%
X_test.shape
# Out:
# (1591, 12943)

# %%
X_train.shape
# Out:
# (2121, 12943)

# %%
y_test.shape
# Out:
# (1591, 7)

# %%
y_train.shape
# Out:
# (2121, 7)

# %%
type(X_train['cm1ethrace'])
# Out:
# pandas.core.series.Series

# %%
initial_df.iloc[1]
# Out:
# cm1relf       1
# cf1edu        3
# cm1edu        1
# cf1ethrace    3
# cm1ethrace    3
# Name: 2, dtype: int64

# %%
print(initial_df.shape)
print(grit_y_train.shape)
# Out:
# (714, 6)
# (714,)

# %%
# run this cell to reset dataframes

ytrainres = pd.read_csv('train.csv')
y_train = ytrainres.copy(deep=True)
ytestres = pd.read_csv('test.csv')
y_test = ytestres.copy(deep=True)

# copy series from cleaned_data that match child challengeIDs in train.csv
xtrainres = pd.concat([pd.DataFrame(cleaned_data.loc[cleaned_data['challengeID'] == ID]) 
                     for index, ID in y_train['challengeID'].items()])
X_train = xtrainres.copy(deep=True)

# copy series from cleaned_data that match child challengeIDs in test.csv
xtestres = pd.concat([pd.DataFrame(cleaned_data.loc[cleaned_data['challengeID'] == ID]) 
                    for index, ID in y_test['challengeID'].items()])
X_test = xtestres.copy(deep=True)

# %%
print(id(X_train))
print(id(xtrainres))

print(id(X_test))
print(id(xtestres))

xtrainres
# Out:
# 4554490880
# 8380798792
# 6801582232
# 7745814600
#       challengeID  m1intmon  m1intyr  m1lenhr  m1lenmin  cm1twoc  cm1fint  \
# 0               1         1      1.0        1        40      1.0        0
# 2               3         1      1.0        0        35      1.0        1
# 5               6         1      1.0        0        25      1.0        1
# 6               7         1      1.0        0        35      1.0        1
# 7               8         1      1.0        1        10      1.0        1
# 8               9         1      1.0        0        30      1.0        1
# 9              10         1      1.0        0        33      1.0        1
# 12             13         1      1.0        1         1      1.0        1
# 13             14         1      1.0        0        25      1.0        1
# 15             16         1      1.0        0        30      1.0        1
# 17             18         1      1.0        0        35      1.0        1
# ...

# %%
X_train
# Out:
#       challengeID  m1intmon  m1intyr  m1lenhr  m1lenmin  cm1twoc  cm1fint  \
# 0               1         1      1.0        1        40      1.0        0
# 2               3         1      1.0        0        35      1.0        1
# 5               6         1      1.0        0        25      1.0        1
# 6               7         1      1.0        0        35      1.0        1
# 7               8         1      1.0        1        10      1.0        1
# 8               9         1      1.0        0        30      1.0        1
# 9              10         1      1.0        0        33      1.0        1
# 12             13         1      1.0        1         1      1.0        1
# 13             14         1      1.0        0        25      1.0        1
# 15             16         1      1.0        0        30      1.0        1
# 17             18         1      1.0        0        35      1.0        1
# 19             20         1      1.0        1        25      1.0        0
# ...

# %%
# read train.csv into pandas DataFrame
outcome = 'gpa'
model = SVR()

# use the quick start constructed variables as features
initial_df = pd.DataFrame([i for i in range(y_train[outcome].shape[0])])
#initial_df = pd.DataFrame(X_train['cm1ethrace'])
initial_df.insert(0, 'cm1ethrace', X_train['cm1ethrace'])
initial_df.insert(1, 'cf1ethrace', X_train['cf1ethrace'])
initial_df.insert(2, 'cm1edu', X_train['cm1edu'])
initial_df.insert(3, 'cf1edu', X_train['cf1edu'])
initial_df.insert(4, 'cm1relf', X_train['cm1relf'])

grit_y_train = y_train[outcome].copy(deep=True)
for item in grit_y_train.iteritems():
    if math.isnan(item[1]):
        grit_y_train.drop(item[0], inplace=True)
        initial_df.drop(item[0], inplace=True)
        
for item in initial_df.itertuples():
    if math.isnan(item[1]):
        initial_df.drop(item[0], inplace=True)
        grit_y_train.drop(item[0], inplace=True)

# do the same for the test data
# use the quick start constructed variables as features
test_initial_df = pd.DataFrame([i for i in range(y_test[outcome].shape[0])])
#initial_df = pd.DataFrame(X_train['cm1ethrace'])
test_initial_df.insert(0, 'cm1ethrace', X_test['cm1ethrace'])
test_initial_df.insert(1, 'cf1ethrace', X_test['cf1ethrace'])
test_initial_df.insert(2, 'cm1edu', X_test['cm1edu'])
test_initial_df.insert(3, 'cf1edu', X_test['cf1edu'])
test_initial_df.insert(4, 'cm1relf', X_test['cm1relf'])

grit_y_test = y_test[outcome].copy(deep=True)
for item in grit_y_test.iteritems():
    if math.isnan(item[1]):
        grit_y_test.drop(item[0], inplace=True)
        test_initial_df.drop(item[0], inplace=True)
        
for item in test_initial_df.itertuples():
    if math.isnan(item[1]):
        test_initial_df.drop(item[0], inplace=True)
        grit_y_test.drop(item[0], inplace=True)

# %%
# reg = model.fit(initial_df, grit_y_train)
# evaluate the model on the training data (this should result in very low error)
print("Training data:")
print(reg.score(initial_df, grit_y_train))
print(mean_squared_error(reg.predict(initial_df), grit_y_train))

print("Testing data")
print(reg.score(test_initial_df, grit_y_test))
print(mean_squared_error(reg.predict(test_initial_df), grit_y_test))
# Out:
# Training data:
# -1.0174341642323923
# 0.8531401047805771
# Testing data
# -0.5730789913751675
# 0.6611453404253973
